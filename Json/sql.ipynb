# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv

# Specify the file path for the CSV file
csv_file = 'AGI.csv'  # Replace with your desired file name and path

# Define the CSV file's header (column names)
fieldnames = ["ZIPCODE",
              "Total Income per Individual",
              "Lacking Health Insurance",
              "Binge Drinking",
              "High Blood Pressure",
              "(Non-Skin) Cancer",
              "Coronary Heart Disease",
              "Routine Health Checkups",
              "Currently Smoking",
              "Dentist Visits",
              "Depression",
              "Diabetes",
              "High Cholesterol",
              "Chronic Kidney Disease",
              "No Leisure-Time Physical Activity",
              "Obesity",
              "Less than 7 Hours of Sleep,Stroke"]

# Open the CSV file in write mode and write the data
with open(csv_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    # Write the header row
    writer.writeheader()

    # Write the data rows
    for row in data:
        writer.writerow(row)

print(f'Data exported to {csv_file}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 33
#      30     writer.writeheader()
#      32     # Write the data rows
# ---> 33     for row in data:
#      34         writer.writerow(row)
#      36 print(f'Data exported to {csv_file}')
#
# NameError: name 'data' is not defined

# %%
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/test_db")

# %%
session = Session(engine)

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
